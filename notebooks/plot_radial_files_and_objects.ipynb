# %%
from pathlib import Path

from hfradar.src.radials import Radial
from hfradar.plotting.plot_nc import plot_radials as ncradialsplot

# %%
velocity_min = 0
velocity_max = 15
sub = 3
title = 'WERA HF Radar'

radial_ruv = Path('../hfradar/data/radials/ruv/WERA/RDL_csw_2019_10_24_162300.ruv')
qc_radial_nc = Path('../output/RDL_csw_2019_10_24_162300.nc')

radial = Radial(radial_ruv)

# Mask the land
radial.mask_over_land()

# Then perform QC
radial.qc_qartod_radial_count()
radial.qc_qartod_valid_location()
radial.qc_qartod_maximum_velocity()
radial.qc_qartod_spatial_median()
radial.export(str(qc_radial_nc), file_type='netcdf-tabular')

# Plot it from netCDF file
ncradialsplot(qc_radial_nc, velocity_min=velocity_min, velocity_max=velocity_max, sub=sub, title=title)

# Plot it from xarray object
ncradialsplot(radial.to_xarray_tabular(enhance=True), velocity_min=velocity_min, velocity_max=velocity_max, sub=sub, title=title)
# Out:
# WARNING:hfradar.src.radials:qc_qartod_valid_location not run, no VFLG column
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1114: RuntimeWarning: All-NaN slice encountered
#   overwrite_input=overwrite_input)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
velocity_min = 0
velocity_max = 15
sub = 1
title = 'CODAR HF Radar'

radial_ruv = Path('../hfradar/data/radials/ruv/SEAB/RDLi_SEAB_2019_01_01_0700.ruv')
qc_radial_nc = Path('../output/RDLi_SEAB_2019_01_01_0700.nc')

radial = Radial(radial_ruv)

# Mask the land
radial.mask_over_land()

# Then perform QC
radial.qc_qartod_radial_count()
radial.qc_qartod_valid_location()
radial.qc_qartod_maximum_velocity()
radial.qc_qartod_spatial_median()
radial.export(str(qc_radial_nc), file_type='netcdf-multidimensional')

# Plot it from netCDF file
ncradialsplot(qc_radial_nc, velocity_min=velocity_min, velocity_max=velocity_max, sub=sub, title=title)

# Plot it from xarray object
ncradialsplot(radial.to_xarray_multidimensional(enhance=True), velocity_min=velocity_min, velocity_max=velocity_max, sub=sub, title=title)
# Out:
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1114: RuntimeWarning: All-NaN slice encountered
#   overwrite_input=overwrite_input)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/oceans/ocfis.py:35: RuntimeWarning: invalid value encountered in sin
#   u = spd * np.sin(ang)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/oceans/ocfis.py:36: RuntimeWarning: invalid value encountered in cos
#   v = spd * np.cos(ang)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1841: RuntimeWarning: invalid value encountered in cos
#   u, v = self.projection.transform_vectors(t, x, y, u, v)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1841: RuntimeWarning: invalid value encountered in sin
#   u, v = self.projection.transform_vectors(t, x, y, u, v)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/oceans/ocfis.py:35: RuntimeWarning: invalid value encountered in sin
#   u = spd * np.sin(ang)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/oceans/ocfis.py:36: RuntimeWarning: invalid value encountered in cos
#   v = spd * np.cos(ang)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1841: RuntimeWarning: invalid value encountered in cos
#   u, v = self.projection.transform_vectors(t, x, y, u, v)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1841: RuntimeWarning: invalid value encountered in sin
#   u, v = self.projection.transform_vectors(t, x, y, u, v)
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/mikesmith/miniconda3/envs/hfradar/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
